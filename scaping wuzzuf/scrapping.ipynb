# %%
import requests

# %%
url="https://wuzzuf.net/search/jobs/?q=ai%20enginner&a=hpb"

# %%
requests.get(url)
# Out:
# <Response [200]>

# %%
website=requests.get(url).text

# %%
website
# Out:
# '<!DOCTYPE html>\n<html lang="en" translate="no">\n<head>\n    <meta charset="utf-8">\n    <meta http-equiv="X-UA-Compatible" content="IE=edge">\n    <meta name="viewport" content="width=device-width, initial-scale=1.0, shrink-to-fit=no">\n    <meta http-equiv="expires" content="Thu Dec 08 2022 18:30:44 GMT+0200" />\n\n    <meta http-equiv="Pragma" content="no-cache">\n    <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate">\n    <meta name="googlebot" content="notranslate">\n    <title data-react-helmet="true">107 ai enginner jobs in Egypt – discover job details now on Wuzzuf!</title>\n\n<meta data-react-helmet="true" charset="utf-8"/><meta data-react-helmet="true" name="description" content="Explore 107 ai enginner jobs in Egypt.  Apply for great job opportunities in leading companies with Wuzzuf today!"/><meta data-react-helmet="true" name="keywords" content="jobs in Egypt, job in Egypt, careers egypt, jobs in Cairo, jobs in alexandria, employment in egy
# ...

# %%
type(website)
# Out:
# str

# %%
from bs4 import BeautifulSoup

# %%
mywebsite= BeautifulSoup(website,"html")

# %%
mywebsite
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0, shrink-to-fit=no" name="viewport"/>
# <meta content="Thu Dec 08 2022 18:30:44 GMT+0200" http-equiv="expires"/>
# <meta content="no-cache" http-equiv="Pragma"/>
# <meta content="no-cache, no-store, must-revalidate" http-equiv="cache-control"/>
# <meta content="notranslate" name="googlebot"/>
# <title data-react-helmet="true">107 ai enginner jobs in Egypt – discover job details now on Wuzzuf!</title>
# ...

# %%
print(mywebsite.title)
# Out:
# <title data-react-helmet="true">107 ai enginner jobs in Egypt – discover job details now on Wuzzuf!</title>

# %%
print(mywebsite.title.text)
# Out:
# 107 ai enginner jobs in Egypt – discover job details now on Wuzzuf!

# %%
jop1=mywebsite.find("div",class_="css-pkv5jc")

# %%
jop1
# Out:
# <div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/Skarpt Company-Egypt-94099" rel="noreferrer" target="_blank"><style data-emotion="css 17095x3">.css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style><img alt="Jobs and Careers at Skarpt Company  Egypt" class="css-17095x3" height="90" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/443576295651c1b9307e51.png?height=90&amp;width=90" style="opacity:0;transition:opacity 0.2s ease-in-out" width="90"/></a><style data-emotion="css laomuu">.css-laomuu{padding-right:60px;}</style><div class="css-laomuu"><style data-emotion="css m604qf">.css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}</style><h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="https
# ...

# %%
jop1.find("a",class_="css-o171kl").text
# Out:
# 'Senior AI Vision Engineer – Computer Vision & Edge Deployment'

# %%
title=jop1.find("a",class_="css-o171kl").text

# %%
title
# Out:
# 'Senior AI Vision Engineer – Computer Vision & Edge Deployment'

# %%
company=jop1.find("a",class_="css-17s97q8").text

# %%
company
# Out:
# 'Skarpt Company  -'

# %%
location=jop1.find("span",class_="css-5wys0k").text

# %%
location
# Out:
# '6th of October, Giza, Egypt '

# %%
tare2=jop1.find("div",class_="css-4c4ojb").text

# %%
tare2
# Out:
# '6 days ago'

# %%
jops=mywebsite.find_all("div",class_="css-pkv5jc")

# %%
jops
# Out:
# [<div class="css-pkv5jc"><a href="https://wuzzuf.net/jobs/careers/Skarpt Company-Egypt-94099" rel="noreferrer" target="_blank"><style data-emotion="css 17095x3">.css-17095x3{position:absolute;right:0;top:0;width:60px;height:60px;object-fit:contain;object-position:center center;}</style><img alt="Jobs and Careers at Skarpt Company  Egypt" class="css-17095x3" height="90" loading="lazy" src="https://images.wuzzuf-data.net/files/company_logo/443576295651c1b9307e51.png?height=90&amp;width=90" style="opacity:0;transition:opacity 0.2s ease-in-out" width="90"/></a><style data-emotion="css laomuu">.css-laomuu{padding-right:60px;}</style><div class="css-laomuu"><style data-emotion="css m604qf">.css-m604qf{font-size:16px;font-weight:600;font-style:normal;letter-spacing:-0.4px;line-height:24px;color:#0055D9;margin:0;}</style><h2 class="css-m604qf"><style data-emotion="css o171kl">.css-o171kl{-webkit-text-decoration:none;text-decoration:none;color:inherit;}</style><a class="css-o171kl" href="http
# ...

# %%
len(jops)
# Out:
# 15

# %%
for jop in jops:
     title=jop.find("a",class_="css-o171kl").text
     company=jop.find("a",class_="css-17s97q8").text
     location=jop.find("span",class_="css-5wys0k").text
print(title,company,location,tare2)
# Out:
# Senior AI Developer Global Brands - New Cairo, Cairo, Egypt  6 days ago

# %%
https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start=1
https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start=2
https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start=3
# Out:
#   Cell In[27], line 1
#     https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start=1
#                                                 ^
# SyntaxError: invalid decimal literal

# %%
for i in range(4):
  url=f"https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start={1}"
  website=requests.get(url).text
  mywebsite= BeautifulSoup(website,"html")
  for jop in jops :
         title=jop.find("a",class_="css-o171kl").text
         company=jop.find("a",class_="css-17s97q8").text
         location=jop.find("span",class_="css-5wys0k").text
         print(title,company,location)
# Out:
# Senior AI Vision Engineer – Computer Vision & Edge Deployment Skarpt Company  - 6th of October, Giza, Egypt
# AI Engineer Pure Group  - Cairo, Egypt
# AI Engineer - Real Estate (Remote) Opal Estate Dubai - New Cairo, Cairo, Egypt
# AI Engineering Manager Link Development - Cairo, Egypt
# Senior AI Engineer Lumin - Sheikh Zayed, Giza, Egypt
# AI Engineer Quantanite - Maadi, Cairo, Egypt
# Python Team Lead - AI & Python Engineering Softec Technologies - Cairo, Egypt
# Full-Stack AI Tool Developer (React, Next.js, PostgreSQL, AWS Lambda) Confidential - New Cairo, Cairo, Egypt
# AI Solutions Architect Get AI Driven - Cairo, Egypt
# AI Agent Developer Confidential - Heliopolis, Cairo, Egypt
# Artificial Intelligence Engineer (NLP) DIRAC SYSTEMS - Heliopolis, Cairo, Egypt
# AI & Software Trainer compsoft - Giza, Egypt
# AI Prompt and Business Integrator - Full Time Remotely Confidential - Sidi Bishr, Alexandria, Egypt
# Automation & Systems Specialist Confidential - Cairo, Egypt
# ...

# %%
import csv

# %%
csvfile=open("wazafha.csv","w",encoding="utf-8")
writer=csv.writer(csvfile)

# %%
writer.writerow(["title","company","location"])
# Out:
# 24

# %%
for i in range(4):
  url=f"https://wuzzuf.net/search/jobs/?a=hpb&q=ai%20enginner&start={i}"
  website=requests.get(url).text
  mywebsite= BeautifulSoup(website,"html")
  for jop in jops :
         title=jop.find("a",class_="css-o171kl").text
         company=jop.find("a",class_="css-17s97q8").text
         location=jop.find("span",class_="css-5wys0k").text
         print(title,company,location)
         writer.writerow([title,company,location])
csvfile.close()
# Out:
# Senior AI Vision Engineer – Computer Vision & Edge Deployment Skarpt Company  - 6th of October, Giza, Egypt
# AI Engineer Pure Group  - Cairo, Egypt
# AI Engineer - Real Estate (Remote) Opal Estate Dubai - New Cairo, Cairo, Egypt
# AI Engineering Manager Link Development - Cairo, Egypt
# Senior AI Engineer Lumin - Sheikh Zayed, Giza, Egypt
# AI Engineer Quantanite - Maadi, Cairo, Egypt
# Python Team Lead - AI & Python Engineering Softec Technologies - Cairo, Egypt
# Full-Stack AI Tool Developer (React, Next.js, PostgreSQL, AWS Lambda) Confidential - New Cairo, Cairo, Egypt
# AI Solutions Architect Get AI Driven - Cairo, Egypt
# AI Agent Developer Confidential - Heliopolis, Cairo, Egypt
# Artificial Intelligence Engineer (NLP) DIRAC SYSTEMS - Heliopolis, Cairo, Egypt
# AI & Software Trainer compsoft - Giza, Egypt
# AI Prompt and Business Integrator - Full Time Remotely Confidential - Sidi Bishr, Alexandria, Egypt
# Automation & Systems Specialist Confidential - Cairo, Egypt
# ...

# %%
csvfile.close()
